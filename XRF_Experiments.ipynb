# %% [markdown]
# <figure>
# <img src='Hdf5_gui/_images/logo.jpg'/>
# </figure>
#
#
#  <h1 style="color:red ;text-align:center" > Jupyter Functions for X-ray Spectroscopy (XRF)</h1>
# <h2 style="color:blue; text-align:center"> In each line, click on the line and press <i>Ctrl+Enter</i> or click on the button to call the function.<br><br>
# <a href=http://www.cnpem.br style="color=blue; target:blank; text-decoration:none"> For more information, click here. </a>

# %% [markdown]
# <h1 style="color:red;text-align:justify"> The line below is necessary to use the other functions. Click on the line and press <i>Ctrl+Enter</i> </h1>

# %%
from Hdf5_gui.XRF_gui import XRF_gui
import ipywidgets as wg
from IPython.display import display

# %% [markdown]
# <h2 style="color: blue"> Click the button below to open the XRF interface (Windows)</h2>
# <h2><a href=http://www.cnpem.br> Click here to open the tutorial. </a></h2>

# %%
botao=wg.Button(description='Run XRF interface')
def f(b):
    
    XRF_gui()
    
botao.on_click(f)
display(botao)
# Out:
# Button(description='Run XRF interface', style=ButtonStyle())

# %% [markdown]
# <h2 style="color:blue"> the line below opens the XRF interface. It is necessary to use the functions below </h2>

# %%
ROI, Data=XRF_gui()
# Out:
# Select an energy level

# %% [markdown]
# <h2 style="color:blue"> the line below opens the XRF 1D plot </h2>

# %%
# %matplotlib notebook
Data.XRF_exp()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h2 style="color:blue"> The line below opens the RGB images (must select only 3 elements on the interface)</h2>

# %%
# %matplotlib notebook
Data.plot_RGB(ROI)
# Out:
# <img src="data:image/png;base64,..." width="902">

# %% [markdown]
# <h2 style="color:blue"> the line below opens the XRF 2D images </h2>

# %%
# %matplotlib notebook
Data.plot_ROI(ROI)
# Out:
# <img src="data:image/png;base64,..." width="1137">

# %% [markdown]
# <h2 style="color:blue"> the line below opens the XRF interface (Linux)  </h2>

# %%
import
