# %% [markdown]
# # Análise de dados da linha Carnaúba

# %%
from Carnauba_exp import*

# %% [markdown]
# ## 1- Selecionar aqui o arquivo a ser estudado:
#    ### Colocar archive='name' onde name é o diretório do arquivo
# # ------------------------------------------#

# %%
archive='C:/Users/Carlos/Desktop/Dados_Sirius/data_mca_0000.hdf'
archive1='C:/Users/Carlos/Desktop/Dados_Sirius/Jarosita Bio 2'

# %% [markdown]
# # ------------------------------------------#

# %% [markdown]
# # Dados de XRF/XAS/XANES

# %%
# %matplotlib notebook
Data = hdf5File(archive)
Data.XRF_data()
#Data.XRF_exp()

#Data1=hdf5File(archive1)
#Data1.XAS_data()
#Data1.XANES_exp()

# %%
Data.XRF_exp()
# Out:
# <img src="data:image/png;base64,..." width="968">

# %% [markdown]
# ###  2- Selecionar a região de interesse para fazer a integração do pixel
# #### ROImin: canal onde começa a integração
# #### ROImax: canal onde termina a integração
# #### xpixel: tamanho do pixel no eixo x
# #### ypixel: tamanho do pixel no eixo y
# #### tittle: Nome do gráfico entre aspas.
# #### eixox: nome da coordenada x entre aspas
# #### eixoy: nome da coordenada y entre aspas
#
# # ------------------------------------------#

# %%
ROImin=620
ROImax=680
xpixel=0.05 
ypixel=0.05
tittle='Fe'
eixox='[mm]'
eixoy='[mm]'

# %% [markdown]
# # ------------------------------------------#

# %%
# %matplotlib notebook
Data.XRF_2D_img(ROImin,ROImax,xpixel,ypixel,tittle,eixox,eixoy)
# Out:
# <img src="data:image/png;base64,..." width="684">

# %% [markdown]
# ##  3- Caso queira salvar a imagem, selecionar o local a ser salvo e a resolução ('dpi')
# ### Local_para_salvar_arquivo: onde será salvo o arquivo, com nome e formato especificado
# ### resolução_dpi: valor de resolução de 0 a 1000
# # ------------------------------------------#

# %%
Local_para_salvar_arquivo='C:/Users/Carlos/Desktop/Dados_Sirius/vesp.png'
resolução_dpi=1000

# %% [markdown]
# # ------------------------------------------#

# %%
# %matplotlib inline
Data.XRF_save_img(Local_para_salvar_arquivo,resolução_dpi,tittle,eixox,eixoy)

# %%
#Calibração do Eixo X
Data.XRF_Energy_calib()
#Data.save_csv()

# %%
# %matplotlib notebook
ROI1=[620,680,'Example1']
ROI2=[340,400,'Example2']
ROI3=[1270,1350,'Example3']
ROI=[ROI1,ROI2,ROI3]
Data.plot_ROI(ROI)
# Out:
# <img src="data:image/png;base64,..." width="939">

# %% [markdown]
# ## lista de funções do programa:
# ### XRF_exp() : Gera gráficos 1D de XRF
# ### XAS_exp() : Gera gráficos 1D de XAS
#
# ### Data.XRF_2D_img(ROImin,ROImax,xpixel,ypixel,tittle,eixox,eixoy)
# ### Data.XRF_save_img(Local_para_salvar_arquivo,resolução_dpi,tittle,eixox,eixoy)
